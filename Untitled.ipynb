# %%
import pandas as pd
import numpy as np# for onehot
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score

# %%
#pip install numpy --upgrade

# %%
#pip install --upgrade scikit-learn

# %%
#conda update -n base -c defaults conda

# %%
#conda install -c conda-forge imbalanced-learn

# %%
df=pd.read_csv('train_u6lujuX_CVtuZ9i.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
x=df #shift +tab

# %%
x.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
#x.nunique()# for seeing if theree is no uppercase

# %% [markdown]
# # EDA

# %%
# count plot on single categorical variable
sns.countplot(x ='Gender', data = x)
 
# Show the plot
plt.show()
sns.countplot(x ='Dependents', data = x)
 
# Show the plot
plt.show()
sns.countplot(x ='Self_Employed', data = x)
 
# Show the plot
plt.show()
sns.countplot(x ='Loan_Status', data = x)
 
# Show the plot
plt.show()
sns.countplot(x ='Property_Area', data =x)
 
# Show the plot
plt.show()

# %%
x.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
sns.heatmap(x.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
x.boxplot(column='LoanAmount')

# %%
x.boxplot(column='Loan_Amount_Term')

# %%
x.boxplot(column='Credit_History')

# %%
x['LoanAmount'].fillna(value=x['LoanAmount'].median(), inplace=True)
x['Loan_Amount_Term'].fillna(value=x['Loan_Amount_Term'].median(), inplace=True)
x['Credit_History'].fillna(value=x['Credit_History'].median(), inplace=True)

# %%
x= pd.get_dummies(x, columns = ['Gender','Married','Dependents','Education', 'Self_Employed','Property_Area','Loan_Status'])

# %%
x=x.drop(['Loan_ID','Gender_Male','Married_Yes','Dependents_3+','Education_Graduate','Self_Employed_Yes','Property_Area_Urban','Loan_Status_N'], axis = 1)

# %%
x
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History  Gender_Female  Married_No  Dependents_0  Dependents_1  \
# ...

# %%
#x=x.dropna()

# %%
x
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History  Gender_Female  Married_No  Dependents_0  Dependents_1  \
# ...

# %%
y=x['Loan_Status_Y']
temp=x.drop(['Loan_Status_Y'], axis = 1)

# %%
from imblearn.combine import SMOTETomek

# %%
smk=SMOTETomek(random_state=42)
X_res,y_res=smk.fit_sample(temp,y)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_res, y_res, test_size=0.10, random_state=42)

# %%
plt.figure(figsize=(11,10))
corr=X_train.corr()
sns.heatmap(corr,annot=True,cmap=plt.cm.CMRmap_r)
plt.show()

# %%
"""def correlation(dataset,thresold):
    col_corr=set()
    corr_mat=corr
    for i in range(len(corr_mat.columns)):
        for j in range(i):
            if(corr_mat.iloc[i,j]>thresold):
                col_corr.add(corr.columns[i])
    return col_corr"""
# Out:
# 'def correlation(dataset,thresold):\n    col_corr=set()\n    corr_mat=corr\n    for i in range(len(corr_mat.columns)):\n        for j in range(i):\n            if(corr_mat.iloc[i,j]>thresold):\n                col_corr.add(corr.columns[i])\n    return col_corr'

# %%
#features=correlation(X_train,0.7)

# %%
#features

# %%
#!pip install numpy==1.16.5

# %%
sns.pairplot(x,hue='Loan_Status_Y',diag_kws={'bw': 0.2})

# %% [markdown]
# # Models

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
"""err=[]
for i in range(1,40):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pre_i=knn.predict(X_val)
    err.append(np.mean(pre_i!=y_val))"""
# Out:
# 'err=[]\nfor i in range(1,40):\n    knn=KNeighborsClassifier(n_neighbors=i)\n    knn.fit(X_train,y_train)\n    pre_i=knn.predict(X_val)\n    err.append(np.mean(pre_i!=y_val))'

# %%
acc=[]
for i in range(1,40):
    knn=KNeighborsClassifier(n_neighbors=i)
    score=cross_val_score(knn,temp,y)#defauly use statified cross val
    acc.append(score.mean())

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color='blue',linestyle='dashed',marker='o',markerfacecolor='red',markersize=10)
plt.title('accuracy vs Kval')
plt.xlabel('K')
plt.ylabel('accyracy Rate')
# Out:
# Text(0, 0.5, 'accyracy Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=14)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=14)

# %%
pred=knn.predict(X_val)

# %%
print(confusion_matrix(y_val,pred))
# Out:
# [[27 15]
#  [ 9 21]]

# %%
precision = precision_score(pred, y_val)

# %%
precision
# Out:
# 0.7

# %%
pred=knn.predict(X_val)

# %%
score=accuracy_score(pred,y_val)

# %%
score
# Out:
# 0.6666666666666666

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Dtree= DecisionTreeClassifier()  
Dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
plt.figure(figsize=(40,35))
tree.plot_tree(Dtree,filled=True,fontsize=10)
# Out:
# [Text(0.4511160714285714, 0.9705882352941176, 'X[4] <= 1.0\ngini = 0.5\nsamples = 642\nvalue = [315, 327]'),
#  Text(0.16875, 0.9117647058823529, 'X[2] <= 547.5\ngini = 0.062\nsamples = 187\nvalue = [181, 6]'),
#  Text(0.15446428571428572, 0.8529411764705882, 'X[1] <= 8115.0\ngini = 0.052\nsamples = 186\nvalue = [181, 5]'),
#  Text(0.12589285714285714, 0.7941176470588235, 'X[4] <= 0.001\ngini = 0.043\nsamples = 182\nvalue = [178, 4]'),
#  Text(0.11160714285714286, 0.7352941176470589, 'X[0] <= 4316.5\ngini = 0.081\nsamples = 94\nvalue = [90, 4]'),
#  Text(0.08303571428571428, 0.6764705882352942, 'X[3] <= 183.495\ngini = 0.029\nsamples = 68\nvalue = [67, 1]'),
#  Text(0.06875, 0.6176470588235294, 'X[0] <= 2546.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.054464285714285715, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08303571428571428, 0.5588235294117647, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
# ...

# %%
#post pruning
Dtree= DecisionTreeClassifier(max_depth=8)  
Dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=8)

# %%
y_pred=Dtree.predict(X_val)

# %%
#score=accuracy_score(y_pred,y_val)

# %%
score
# Out:
# 0.6666666666666666

# %%
#print(classification_report(y_val,pred))

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(n_estimators=10,max_depth=10, random_state=42)
RF.fit(X_train, y_train)
result=RF.predict(X_val)

# %%
score=accuracy_score(result,y_val)

# %%
score
# Out:
# 0.8333333333333334

# %%
print(confusion_matrix(y_val,result))
# Out:
# [[31 11]
#  [ 1 29]]

# %%
precision = precision_score(pred, y_val)#prec fp

# %%
precision
# Out:
# 0.7
